# %% [markdown]
# <a href="https://colab.research.google.com/github/RIFAVPZACHARIA/machine--learning-ict/blob/main/linearrg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import pandas
import pandas as pd
import numpy as np

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-99e9b156-e837-49fb-8067-379c72640e01" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-99e9b156-e837-49fb-8067-379c72640e01">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# read CSV file from the 'data' subdirectory using a relative path
data = pd.read_csv('winequality-red.csv', index_col=0)

# display the first 5 rows
data.head(10)
# Out:
#                volatile acidity  citric acid  residual sugar  chlorides
# fixed acidity
# 7.4                        0.70         0.00             1.9      0.076
# 7.8                        0.88         0.00             2.6      0.098
# 7.8                        0.76         0.04             2.3      0.092
# 11.2                       0.28         0.56             1.9      0.075
# 7.4                        0.70         0.00             1.9      0.076
# 7.4                        0.66         0.00             1.8      0.075
# 7.9                        0.60         0.06             1.6      0.069
# 7.3                        0.65         0.00             1.2      0.065
# 7.8                        0.58         0.02             2.0      0.073
# 7.5                        0.50         0.36             6.1      0.071

# %%
# display the last 5 rows
data.tail()
# Out:
#                volatile acidity  citric acid  residual sugar  chlorides
# fixed acidity
# 6.2                       0.600         0.08             2.0      0.090
# 5.9                       0.550         0.10             2.2      0.062
# 6.3                       0.510         0.13             2.3      0.076
# 5.9                       0.645         0.12             2.0      0.075
# 6.0                       0.310         0.47             3.6      0.067

# %%
# check the shape of the DataFrame (rows, columns)
data.shape
# Out:
# (1599, 4)

# %%
# conventional way to import seaborn
import matplotlib.pyplot as plt

# allow plots to appear within the notebook
# %matplotlib inline

# %%
data.plot(kind='scatter',x='fixed acidity',y='chlorides',color='red')
data.plot(kind='scatter',x='volatile acidity',y='chlorides',color='blue')
data.plot(kind='scatter',x='citric acid',y='chlorides',color='green')

# data.reset_index(inplace=True)|
# Out:
# <Axes: xlabel='citric acid', ylabel='chlorides'>

# %%
# create a Python list of feature names
feature_cols = ['fixed acidity', 'volatile acidity', 'citric acid']

# use the list to select a subset of the original DataFrame
X = data[feature_cols]

# equivalent command to do this in one line
X = data[['fixed acidity', 'volatile acidity', 'citric acid']]

# print the first 5 rows
X.head()
# Out:
#    fixed acidity  volatile acidity  citric acid
# 0            7.4              0.70         0.00
# 1            7.8              0.88         0.00
# 2            7.8              0.76         0.04
# 3           11.2              0.28         0.56
# 4            7.4              0.70         0.00

# %%
# check the type and shape of X
print(type(X))
print(X.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (1599, 3)

# %%
# select a Series from the DataFrame
lab = ['chlorides']

# equivalent command that works if there are no spaces in the column name
y =  data['chlorides']



# print the first 5 values
y.head()
# Out:
# 0    0.076
# 1    0.098
# 2    0.092
# 3    0.075
# 4    0.076
# Name: chlorides, dtype: float64

# %%
# check the type and shape of y
print(type(y))
print(y.shape)
# Out:
# <class 'pandas.core.series.Series'>
# (1599,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# default split is 75% for training and 25% for testing
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# X_train = X_train[:150]

print(X_test)
# Out:
# (1199, 3)
# (1199,)
# (400, 3)
# (400,)
#       fixed acidity  volatile acidity  citric acid
# 75              8.8             0.410         0.64
# 1283            8.7             0.630         0.28
# 408            10.4             0.340         0.58
# 1281            7.1             0.460         0.20
# 1118            7.1             0.390         0.12
# ...             ...               ...          ...
# 1416           10.0             0.320         0.59
# 1567            7.2             0.695         0.13
# 1204            7.2             0.360         0.46
# 12              5.6             0.615         0.00
# 584            11.8             0.330         0.49
#
# [400 rows x 3 columns]

# %%
# import model
from sklearn.linear_model import LinearRegression

# instantiate
linreg = LinearRegression()

# fit the model to the training data (learn the coefficients)
model = linreg.fit(X_train, y_train)

# %%
# make predictions on the testing set
y_pred = linreg.predict(X_test)
print(y_pred)
# Out:
# [0.11617503 0.09397209 0.09989686 0.07920207 0.0660567  0.07354018
#  0.08779595 0.11387778 0.08635851 0.07611778 0.0641217  0.06741787
#  0.07372678 0.07517015 0.07772719 0.09043047 0.07486173 0.09628592
#  0.106056   0.09028143 0.08338581 0.07950722 0.08477584 0.0933428
#  0.09607772 0.07025362 0.0762177  0.09609666 0.10315504 0.11575822
#  0.0747257  0.08397857 0.08855668 0.07904444 0.09911871 0.07170498
#  0.09720972 0.06633778 0.06086544 0.07337947 0.09000598 0.08898577
#  0.08816546 0.05760224 0.09276691 0.07934548 0.08518762 0.06939975
#  0.10526261 0.08740648 0.09673006 0.07021903 0.08006139 0.0933647
#  0.11179713 0.10187474 0.0953257  0.10370891 0.07529759 0.07442733
#  0.12471538 0.08619259 0.10164586 0.10182315 0.10814966 0.10497591
#  0.09248553 0.07413058 0.09041922 0.09512773 0.09911871 0.071359
#  0.08494822 0.06137643 0.08135458 0.08473356 0.10288758 0.09845748
#  0.08605686 0.0778236  0.08430622 0.08690112 0.08284453 0.09593177
# ...

# %%
print(X_test)
# Out:
#       fixed acidity  volatile acidity  citric acid
# 75              8.8             0.410         0.64
# 1283            8.7             0.630         0.28
# 408            10.4             0.340         0.58
# 1281            7.1             0.460         0.20
# 1118            7.1             0.390         0.12
# ...             ...               ...          ...
# 1416           10.0             0.320         0.59
# 1567            7.2             0.695         0.13
# 1204            7.2             0.360         0.46
# 12              5.6             0.615         0.00
# 584            11.8             0.330         0.49
#
# [400 rows x 3 columns]
